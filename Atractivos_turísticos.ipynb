# %% [markdown]
# # Preprocesamiento de Datos: Clasificación de Atractivos Turísticos de Medellín

# %% [markdown]
# Este repositorio documenta el preprocesamiento de datos de los principales atractivos turísticos de Medellín. Como parte del análisis, se creó una nueva columna que categoriza cada atractivo en distintos tipos de turismo según su perfil y características.

# %%
# !pip install geopandas
# !pip install geopandas

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import geopandas as gpd
import geopandas as gpd
import matplotlib.pyplot as plt
import zipfile
import os

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eab47bf1-0ec9-4aaf-bbaf-9061814a8b62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eab47bf1-0ec9-4aaf-bbaf-9061814a8b62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gdf = gpd.read_file("Estaciones_EnCicla_AMVA_20241111.csv")

# %%
gdf.head()
# Out:
#    #  NOMBRE ESTACION               DIRECCION  \
# 0  1          Moravia       CALLE 82A # 52-29
# 1  2      Universidad         CALLE 73 # 52-2
# 2  3           Ruta N     CARRERA 52 # 67A-13
# 3  4          Robledo  CARRERA 77A # 63 - 100
# 4  5  Campus Nacional    CALLE 59A # 64C - 44
#
#                                      Ayuda Ubicación               MUNICIPIO  \
# 0  Frente a la entrada principal del Centro de De...    Zona 1 - Nororiental
# 1  Bajo el viaducto de la estación Universidad de...    Zona 1 - Nororiental
# 2  Frente a la fachada principal de Ruta N sobre ...    Zona 1 - Nororiental
# 3             Diagonal al Colegio Mayor de Antioquia  Zona 2 - Noroccidental
# 4  Portería de la Iguaná con Carrera 65 de la Uni...  Zona 2 - Noroccidental
#
#      TIPO TOTAL ANCLAJES  Georeferenciación
# 0  MANUAL             15   6,27658;-75,5648
# 1  MANUAL             33  6,26939;-75,56577
# 2  AUTOM.             40  6,26518;-75,56634
# ...

# %%
gdf.loc[gdf['nombre_sit'] == 'Aeroparque Parque Juan Pablo II','categorias_turismo'] = 'Turismo de aventura'
gdf.loc[gdf['nombre_sit'] == 'Aeropuerto Enrique Olaya Herrera','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Barrio Prado','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Basílica Menor Nuestra Señora de la Candelaria','categorias_turismo'] = 'Turismo religioso'
gdf.loc[gdf['nombre_sit'] == 'Bulevar Libertadores de América','categorias_turismo'] = 'Turismo nocturno'
gdf.loc[gdf['nombre_sit'] == 'Calle de la Buena Mesa','categorias_turismo'] = 'Turismo gastronomico'
gdf.loc[gdf['nombre_sit'] == 'Casa de la Lectura Infantil','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Casa de Música El Jordán','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Casa Museo Maestro Pedro Nel Gómez','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Catedral Basílica Metropolitana de la Inmaculada Concepción de María','categorias_turismo'] = 'Turismo religioso'
gdf.loc[gdf['nombre_sit'] == 'Cementerio San Lorenzo','categorias_turismo'] = 'Turismo religioso'
gdf.loc[gdf['nombre_sit'] == 'Centro Administrativo´José María Córdoba´','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Centro Comercial Palacio Nacional','categorias_turismo'] = 'Centro comercial'
gdf.loc[gdf['nombre_sit'] == 'Centro de Desarrollo Cultural de Moravia','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Centro de Espectáculos La Macarena','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Cerro Pan de Azúcar','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Complejo Arquitectónico Claustro San Ignacio','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Conjunto de Esculturas de Botero','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Ecoparque Cerro Picacho','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Edificio Antigua Estación Medellín','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Edificio Carré','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Edificio Coltejer','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Edificio Inteligente Empresas Públicas de Medellín','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Edificio Vásquez','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Escaleras Eléctricas Comuna 13','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Escultura Cacique Nutibara','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Escultura La Gorda de Botero','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Estatua a Simón Bolívar','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Fuente Cacique de Nutibara','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Iglesia de San Antonio','categorias_turismo'] = 'Turismo religioso'
gdf.loc[gdf['nombre_sit'] == 'Iglesia Jesús de Nazareno','categorias_turismo'] = 'Turismo religioso'
gdf.loc[gdf['nombre_sit'] == 'Iglesia La Veracruz','categorias_turismo'] = 'Turismo religioso'
gdf.loc[gdf['nombre_sit'] == 'Iglesia San José de El Poblado','categorias_turismo'] = 'Turismo religioso'
gdf.loc[gdf['nombre_sit'] == 'Jardín Botánico Joaquín Antonio Uribe','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Jardín Morro de Moravia','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Milla de Oro','categorias_turismo'] = 'Turismo gastronomico'
gdf.loc[gdf['nombre_sit'] == 'Monumento a Carlos Gardel','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Monumento a la Raza','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Monumento a La Vida','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Monumento a la Vida','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Monumento al Tango','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Monumento El Pájaro','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Monumento Paloma de la Paz','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Museo al Aire Libre Acueducto del Siglo XIX','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Museo Casa de la Memoria','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Museo Casa Gardeliana','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Museo Cementerio San Pedro','categorias_turismo'] = 'Turismo religioso'
gdf.loc[gdf['nombre_sit'] == 'Museo de Antioquia','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Museo de Arte Moderno de Medellín','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Museo del Agua','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Museo El Castillo','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Museo Etnográfico Madre Laura','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Palacio de Bellas Artes','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Palacio de la Cultura Rafael Uribe Uribe','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Parque Ambiental Bosques de La Frontera','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Parque Biblioteca España','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Parque de Berrío','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Parque de Bolívar','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Parque de El Poblado','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Parque de los Deseos','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Parque de los Pies Descalzos','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Parque Explora','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Parque Lineal La Presidenta','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Parque Lleras','categorias_turismo'] = 'Turismo nocturno'
gdf.loc[gdf['nombre_sit'] == 'Parque Natural Metropolitano Cerro El Volador','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Parque Natural Metropolitano Cerro Nutibara','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Parque Norte J. Emilio Valderrama','categorias_turismo'] = 'Turismo de aventura'
gdf.loc[gdf['nombre_sit'] == 'Parque Regional Ecoturístico Arví','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Parque de la Conservación','categorias_turismo'] = 'Ecoturismo'
gdf.loc[gdf['nombre_sit'] == 'Paseo Bolívar','categorias_turismo'] = 'Centro comercial'
gdf.loc[gdf['nombre_sit'] == 'Paseo Peatonal Ayacucho','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Paseo Peatonal Carabobo','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Paseo Peatonal de Junín','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Paseo Provenza','categorias_turismo'] = 'Turismo nocturno'
gdf.loc[gdf['nombre_sit'] == 'Pequeño Teatro','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Placita de Flórez','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Planetario Municipal de Medellín Jesús Emilio Ramírez González','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Plaza Botero','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Plaza Cisneros','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Plaza Gardel','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Plaza Mayor Medellín Convenciones y Exposiciones','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Plaza Minorista José María Villa','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Pueblito Paisa','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Puente de Guayaquil','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Santuario Santa Laura Montoya','categorias_turismo'] = 'Turismo religioso'
gdf.loc[gdf['nombre_sit'] == 'Teatro Lido','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Teatro Metropolitano de Medellín José Gutiérrez Gómez','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Teatro Pablo Tobón Uribe','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Teatro Prado el Águila Descalza','categorias_turismo'] = 'Turismo cultural'
gdf.loc[gdf['nombre_sit'] == 'Unidad Deportiva Atanasio Girardot','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Unidad Deportiva de Belén Andrés Escobar Saldarriaga','categorias_turismo'] = ''
gdf.loc[gdf['nombre_sit'] == 'Vía Primavera','categorias_turismo'] = 'Ecoturismo'

# %%
gdf.head()
# Out:
#   imperdible cod_comuna    cod  \
# 0         NO         15  AT001
# 1         NO         15  AT002
# 2         NO         10  AT003
# 3         NO         10  AT004
# 4         NO         11  AT005
#
#                                        nombre_sit  \
# 0                 Aeroparque Parque Juan Pablo II
# 1                Aeropuerto Enrique Olaya Herrera
# 2                                    Barrio Prado
# 3  Basílica Menor Nuestra Señora de la Candelaria
# 4                 Bulevar Libertadores de América
#
#                          tipo_atrac  orden_visu  \
# 0      Parque temático y recreativo          14
# 1           Aeropuerto de pasajeros          37
# 2  Sector urbano o rural de interés           0
# 3                          Basílica          35
# 4  Sector urbano o rural de interés           2
#
#                              direccion  \
# 0                    CR 70 No. 16 - 04
# 1                 CR 65 A No. 13 - 157
# 2                      CR 50 No. 62-99
# ...

# %%
gdf_Sitios_turisticos_categoria = gdf[gdf['categorias_turismo'] != ''].copy()

# %%
data_counts = gdf_Sitios_turisticos_categoria['categorias_turismo'].value_counts()

# Genera el gráfico de pastel
plt.figure(figsize=(8, 8))
plt.pie(data_counts, labels=data_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Distribución de la columna 'categorias_turismo'")
plt.show()

# %%
gdf_Sitios_turisticos_categoria.to_file("/content/Sitios turisticos por categoria.shp")
# Out:
# <ipython-input-16-50ec2e795048>:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_Sitios_turisticos_categoria.to_file("/content/Sitios turisticos por categoria.shp")
# /usr/local/lib/python3.10/dist-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'categorias_turismo' to 'categorias'
#   ogr_write(

# %%
gdf.Georeferenciación

# %%
shapefile_dir = "/content/Sitios turisticos por categoria"  # Nombre base del shapefile
zip_filename = "/content/Sitios turisticos por categoria.zip"

with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for ext in ['.shp', '.shx', '.dbf', '.prj']:
        zipf.write(shapefile_dir + ext, os.path.basename(shapefile_dir + ext))

# %%
from google.colab import files

# Descargar el archivo ZIP
files.download(zip_filename)
